# %%
# !pip install bs4

# %% [markdown]
# - https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&tg=0&date=20200725

# %%
mov_data = 'https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&tg=0&date=20200725'

# %%
import  pandas as pd

# %%
data = pd.read_html(mov_data)

# %%
data
# Out:
# [    순위              영화명  평점  평점.1  평점.2  변동폭  변동폭.1  Unnamed: 7
#  0  NaN              NaN NaN   NaN   NaN  NaN    NaN         NaN
#  1  NaN             가버나움 NaN  9.59  평점주기  NaN    0.0         NaN
#  2  NaN           위대한 쇼맨 NaN  9.40  평점주기  NaN    0.0         NaN
#  3  NaN              알라딘 NaN  9.38  평점주기  NaN    0.0         NaN
#  4  NaN           에이리언 2 NaN  9.35  평점주기  NaN    0.0         NaN
#  5  NaN           다크 나이트 NaN  9.34  평점주기  NaN    0.0         NaN
#  6  NaN          소년시절의 너 NaN  9.32  평점주기  NaN    0.0         NaN
#  7  NaN           시네마 천국 NaN  9.31  평점주기  NaN    0.0         NaN
#  8  NaN      패왕별희 디 오리지널 NaN  9.31  평점주기  NaN    0.0         NaN
#  9  NaN              우리들 NaN  9.26  평점주기  NaN    0.0         NaN
#  10 NaN        피아니스트의 전설 NaN  9.25  평점주기  NaN    0.0         NaN
#  11 NaN              NaN NaN   NaN   NaN  NaN    NaN         NaN
#  12 NaN              톰보이 NaN  9.23  평점주기  NaN    0.0         NaN
# ...

# %%
type(data)
# Out:
# list

# %%
len(data)
# Out:
# 2

# %%
df = data[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 8 columns):
# 순위            0 non-null float64
# 영화명           50 non-null object
# 평점            0 non-null float64
# 평점.1          50 non-null float64
# 평점.2          50 non-null object
# 변동폭           0 non-null float64
# 변동폭.1         49 non-null float64
# Unnamed: 7    0 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 3.6+ KB

# %%
pick = ['순위', '영화명', '평점.1']
df1 = df[pick]

# %%
df1.head()
# Out:
#    순위     영화명  평점.1
# 0 NaN     NaN   NaN
# 1 NaN    가버나움  9.59
# 2 NaN  위대한 쇼맨  9.40
# 3 NaN     알라딘  9.38
# 4 NaN  에이리언 2  9.35

# %%
df1.columns=['랭킹','영화제목','평점']

# %%
df1
# Out:
#     랭킹             영화제목    평점
# 0  NaN              NaN   NaN
# 1  NaN             가버나움  9.59
# 2  NaN           위대한 쇼맨  9.40
# 3  NaN              알라딘  9.38
# 4  NaN           에이리언 2  9.35
# 5  NaN           다크 나이트  9.34
# 6  NaN          소년시절의 너  9.32
# 7  NaN           시네마 천국  9.31
# 8  NaN      패왕별희 디 오리지널  9.31
# 9  NaN              우리들  9.26
# 10 NaN        피아니스트의 전설  9.25
# 11 NaN              NaN   NaN
# 12 NaN              톰보이  9.23
# 13 NaN          스타 이즈 본  9.18
# 14 NaN              싸이코  9.11
# 15 NaN      타오르는 여인의 초상  9.05
# 16 NaN          미스비헤이비어  9.04
# 17 NaN           인생 후르츠  9.02
# 18 NaN              미져리  9.02
# 19 NaN     안녕, 나의 소울메이트  8.97
# 20 NaN    온워드: 단 하루의 기적  8.96
# 21 NaN               미션  8.93
# 22 NaN              NaN   NaN
# 23 NaN     바르다가 사랑한 얼굴들  8.89
# 24 NaN        트롤: 월드 투어  8.86
# 25 NaN          시티 오브 갓  8.84
# 26 NaN           미녀와 야수  8.78
# 27 NaN    부에나 비스타 소셜 클럽  8.78
# 28 NaN              소공녀  8.77
# 29 NaN               벌새  8.76
# ...

# %%
pick = ['랭킹','영화제목','평점']

# %%
df2 = df1.dropna(how = 'all')

# %%
df2
# Out:
#     랭킹             영화제목    평점
# 1  NaN             가버나움  9.59
# 2  NaN           위대한 쇼맨  9.40
# 3  NaN              알라딘  9.38
# 4  NaN           에이리언 2  9.35
# 5  NaN           다크 나이트  9.34
# 6  NaN          소년시절의 너  9.32
# 7  NaN           시네마 천국  9.31
# 8  NaN      패왕별희 디 오리지널  9.31
# 9  NaN              우리들  9.26
# 10 NaN        피아니스트의 전설  9.25
# 12 NaN              톰보이  9.23
# 13 NaN          스타 이즈 본  9.18
# 14 NaN              싸이코  9.11
# 15 NaN      타오르는 여인의 초상  9.05
# 16 NaN          미스비헤이비어  9.04
# 17 NaN           인생 후르츠  9.02
# 18 NaN              미져리  9.02
# 19 NaN     안녕, 나의 소울메이트  8.97
# 20 NaN    온워드: 단 하루의 기적  8.96
# 21 NaN               미션  8.93
# 23 NaN     바르다가 사랑한 얼굴들  8.89
# 24 NaN        트롤: 월드 투어  8.86
# 25 NaN          시티 오브 갓  8.84
# 26 NaN           미녀와 야수  8.78
# 27 NaN    부에나 비스타 소셜 클럽  8.78
# 28 NaN              소공녀  8.77
# 29 NaN               벌새  8.76
# 30 NaN              현기증  8.73
# 31 NaN        바닷마을 다이어리  8.73
# 32 NaN           베스트 오퍼  8.65
# ...

# %%
df2.shape
# Out:
# (50, 3)

# %%
df2['랭킹'] = range(1, len(df2)+1)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#     랭킹             영화제목    평점
# 1    1             가버나움  9.59
# 2    2           위대한 쇼맨  9.40
# 3    3              알라딘  9.38
# 4    4           에이리언 2  9.35
# 5    5           다크 나이트  9.34
# 6    6          소년시절의 너  9.32
# 7    7           시네마 천국  9.31
# 8    8      패왕별희 디 오리지널  9.31
# 9    9              우리들  9.26
# 10  10        피아니스트의 전설  9.25
# 12  11              톰보이  9.23
# 13  12          스타 이즈 본  9.18
# 14  13              싸이코  9.11
# 15  14      타오르는 여인의 초상  9.05
# 16  15          미스비헤이비어  9.04
# 17  16           인생 후르츠  9.02
# 18  17              미져리  9.02
# 19  18     안녕, 나의 소울메이트  8.97
# 20  19    온워드: 단 하루의 기적  8.96
# 21  20               미션  8.93
# 23  21     바르다가 사랑한 얼굴들  8.89
# 24  22        트롤: 월드 투어  8.86
# 25  23          시티 오브 갓  8.84
# 26  24           미녀와 야수  8.78
# 27  25    부에나 비스타 소셜 클럽  8.78
# 28  26              소공녀  8.77
# 29  27               벌새  8.76
# 30  28              현기증  8.73
# 31  29        바닷마을 다이어리  8.73
# 32  30           베스트 오퍼  8.65
# ...

# %%
df2.reset_index(drop = True, inplace = True)

# %%
df2
# Out:
#     랭킹             영화제목    평점
# 0    1             가버나움  9.59
# 1    2           위대한 쇼맨  9.40
# 2    3              알라딘  9.38
# 3    4           에이리언 2  9.35
# 4    5           다크 나이트  9.34
# 5    6          소년시절의 너  9.32
# 6    7           시네마 천국  9.31
# 7    8      패왕별희 디 오리지널  9.31
# 8    9              우리들  9.26
# 9   10        피아니스트의 전설  9.25
# 10  11              톰보이  9.23
# 11  12          스타 이즈 본  9.18
# 12  13              싸이코  9.11
# 13  14      타오르는 여인의 초상  9.05
# 14  15          미스비헤이비어  9.04
# 15  16           인생 후르츠  9.02
# 16  17              미져리  9.02
# 17  18     안녕, 나의 소울메이트  8.97
# 18  19    온워드: 단 하루의 기적  8.96
# 19  20               미션  8.93
# 20  21     바르다가 사랑한 얼굴들  8.89
# 21  22        트롤: 월드 투어  8.86
# 22  23          시티 오브 갓  8.84
# 23  24           미녀와 야수  8.78
# 24  25    부에나 비스타 소셜 클럽  8.78
# 25  26              소공녀  8.77
# 26  27               벌새  8.76
# 27  28              현기증  8.73
# 28  29        바닷마을 다이어리  8.73
# 29  30           베스트 오퍼  8.65
# ...
